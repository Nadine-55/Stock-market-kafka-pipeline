# %%
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads 
import json
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer(
    'demo_test2',
    bootstrap_servers=['localhost:9092'], 
    
    auto_offset_reset='latest',
    value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
for c in consumer: 
    print(c.value)

# %%
s3 = S3FileSystem()

# %%
for count, i in enumerate(consumer): 
    with s3.open("s3://kafka-stock-market-nadine-856723974514-eu-west-1-an/stock_market_{}.json".format(count), 'w') as file:
        json.dump(i.value, file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 for count, i in enumerate(consumer):
#       2     with s3.open("s3://kafka-stock-market-nadine-856723974514-eu-west-1-an/stock_market_{}.json".format(count), 'w') as file:
#       3         json.dump(i.value, file)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\consumer\group.py:1213, in KafkaConsumer.__next__(self)
#    1211     self._iterator = self._message_generator_v2()
#    1212 try:
# -> 1213     return next(self._iterator)
#    1214 except StopIteration:
#    1215     self._iterator = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\consumer\group.py:1185, in KafkaConsumer._message_generator_v2(self)
#    1183 def _message_generator_v2(self):
#    1184     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1185     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1186     for tp, records in six.iteritems(record_map):
#    1187         # Generators are stateful, and it is possible that the tp / records
#    1188         # here may become stale during iteration -- i.e., we seek to a
#    1189         # different offset, pause consumption, or lose assignment.
#    1190         for record in records:
#    1191             # is_fetchable(tp) should handle assignment changes and offset
#    1192             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1193             # outer function destroying the existing iterator/generator
#    1194             # via self._iterator = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\consumer\group.py:708, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     706 timer = Timer(timeout_ms)
#     707 while not self._closed:
# --> 708     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     709     if records:
#     710         return records
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\consumer\group.py:743, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     741     futures = self._fetcher.send_fetches()
#     742     if len(futures):
# --> 743         self._client.poll(timeout_ms=0)
#     745 if records:
#     746     return records
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\client_async.py:744, in KafkaClient._poll(self, timeout)
#     742     conn.connect()
#     743 else:
# --> 744     if conn.send_pending_requests_v2():
#     745         # If send is complete, we dont need to track write readiness
#     746         # for this socket anymore
#     747         if key.events ^ selectors.EVENT_WRITE:
#     748             self._selector.modify(
#     749                 key.fileobj,
#     750                 key.events ^ selectors.EVENT_WRITE,
#     751                 key.data)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\conn.py:1082, in BrokerConnection.send_pending_requests_v2(self)
#    1080 total_bytes = 0
#    1081 if self._send_buffer:
# -> 1082     total_bytes = self._send_bytes(self._send_buffer)
#    1083     self._send_buffer = self._send_buffer[total_bytes:]
#    1085 # If all data was sent, we need to get the new data from the protocol now, otherwise
#    1086 # this function would return True, indicating that there are no more pending
#    1087 # requests. This could cause the calling thread to wait indefinitely as it won't
#    1088 # know that there is still buffered data to send.
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\conn.py:718, in BrokerConnection._send_bytes(self, data)
#     716 while total_sent < len(data):
#     717     try:
# --> 718         sent_bytes = self._sock.send(data[total_sent:])
#     719         total_sent += sent_bytes
#     720     except (SSLWantReadError, SSLWantWriteError):
#
# KeyboardInterrupt:
